# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

# %%
img = np.zeros((3,3), dtype=np.uint8)
print(img)

# %%
image = cv2.imread('images/00001-129.jpg')

# %%
randomByte = bytearray(os.urandom(120000))
flatNpArray = np.array(randomByte)
print(flatNpArray)
# Out:
# 63
# [163  63 118 ...  90 173 144]

# %%
grayImage = flatNpArray.reshape(300, 400)
cv2.imwrite('images/1.png', grayImage)
# Out:
# True

# %%
bgrImage = flatNpArray.reshape(100, 400, 3)
cv2.imwrite('images/2.png', bgrImage)
# Out:
# True

# %%
img = cv2.imread('./images/00001-129.jpg')
cv2.imshow('show', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('./images/00001-129.jpg')
Grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# print(Grayimg.shape)
cv2.title("Input Image")
cv2.imshow(Grayimg, cmap="gray")  #显示图片
cv2.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-319e554704e8> in <module>()
#       2 Grayimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       3 # print(Grayimg.shape)
# ----> 4 cv2.title("Input Image")
#       5 cv2.imshow(Grayimg, cmap="gray")  #显示图片
#       6 cv2.show()
#
# AttributeError: module 'cv2.cv2' has no attribute 'title'

# %%
ret,thresh1=cv2.threshold(Grayimg,12,255,cv2.THRESH_BINARY)  
plt.imshow(Grayimg)
# plt.imshow(thresh1)

# %%
from PIL import Image
img = Image.open('./images/00001-129.jpg')
L = img.convert('L')
img1 = np.array(L)
L = img.convert('1')
ret,thresh1=cv2.threshold(img1,100,255,cv2.THRESH_BINARY)  
plt.imshow(Grayimg)
# L.show()
im_at_mean = cv2.adaptiveThreshold(img1, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 5, 10)
# plt.imshow(im_at_mean)
